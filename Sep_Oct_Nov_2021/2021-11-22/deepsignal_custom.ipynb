# %%
import pandas as pd
import numpy as py
import sys, os

# %%
#chrom, pos, alignstrand, loc_in_ref, readname, strand,
#k_mer, signal_means, signal_stds, signal_lens,
#cent_signals, methy_label
input_path='/fastscratch/c-panz/2021-11-22/deepsignal_custom/'
df_5hmC=pd.read_csv(os.path.join(input_path, 'T4_5hmC.tsv'),
                    sep = '\t', header = None)
df_5hmC
# Out:
#               0       1  2       3                                     4  5   \
# 0     KJ477685.1   51868  -  114947  0f05c8bc-6fcf-4757-9127-e2b9fc5e6072  t
# 1     KJ477685.1   51812  -  115003  0f05c8bc-6fcf-4757-9127-e2b9fc5e6072  t
# 2     KJ477685.1   51779  -  115036  0f05c8bc-6fcf-4757-9127-e2b9fc5e6072  t
# 3     KJ477685.1   51760  -  115055  0f05c8bc-6fcf-4757-9127-e2b9fc5e6072  t
# 4     KJ477685.1   51727  -  115088  0f05c8bc-6fcf-4757-9127-e2b9fc5e6072  t
# ...          ...     ... ..     ...                                   ... ..
# 2959  KJ477685.1  164025  -    2790  ea52acf2-f6ba-4ed8-a5ec-5f631a607f99  t
# 2960  KJ477685.1  164019  -    2796  ea52acf2-f6ba-4ed8-a5ec-5f631a607f99  t
# 2961  KJ477685.1  164016  -    2799  ea52acf2-f6ba-4ed8-a5ec-5f631a607f99  t
# 2962  KJ477685.1  164000  -    2815  ea52acf2-f6ba-4ed8-a5ec-5f631a607f99  t
# 2963  KJ477685.1  163986  -    2829  ea52acf2-f6ba-4ed8-a5ec-5f631a607f99  t
#
#                      6                                                  7   \
# 0     GCAGTGAGCGCTTGGTT  -0.297233,0.627491,-0.951716,-0.830727,1.14232...
# 1     TACAAGACCGTTCCTCT  0.67449,0.530446,0.787177,0.143535,-0.198155,-...
# 2     ATCAACTACGGAGGAAC  -0.237215,0.964101,0.950664,-0.765426,-0.55635...
# 3     AAAATGAACGCTAAAGA  0.044095,-0.118131,-0.5354,-0.431727,1.60865,-...
# 4     AATTACAACGATGGTAA  -0.754514,-1.043677,0.928852,0.842159,0.221496...
# ...                 ...                                                ...
# 2959  TTGAGCGTCGACTGCGA  1.128094,1.067942,-0.569963,-1.171482,-0.95848...
# 2960  GTCGACTGCGACGAGTA  -1.223548,0.382605,0.26143,-1.07238,-0.686323,...
# 2961  GACTGCGACGAGTAATT  -1.07238,-0.686323,0.337955,0.315551,-0.110443...
# 2962  TTAATGGCCGTGTGTAT  0.660788,1.101061,-0.315235,-0.157775,1.257542...
# 2963  TATTCATGCGGCCTTGG  0.475693,-1.003034,0.662657,0.620583,0.166979,...
#
#                                                      8   \
# 0     0.174876,0.143136,0.084541,0.18323,0.122837,0....
# 1     0.087064,0.200449,0.138192,0.255861,0.100677,0...
# 2     0.088136,0.08673,0.265818,0.143842,0.046045,0....
# 3     0.196345,0.055484,0.161325,0.098305,0.075018,0...
# 4     0.192882,0.093925,0.15012,0.099807,0.048143,0....
# ...                                                 ...
# 2959  0.247147,0.072644,0.214298,0.045446,0.033469,0...
# 2960  0.082866,0.405831,0.29031,0.119792,0.246705,0....
# 2961  0.119792,0.246705,0.091542,0.056613,0.272477,0...
# 2962  0.113322,0.137052,0.162002,0.133294,0.151041,0...
# 2963  0.539021,0.129086,0.164249,0.049615,0.191166,0...
#
#                                                 9   \
# 0           3,18,4,3,13,6,20,3,14,8,3,26,3,5,5,9,3
# 1           5,5,7,27,3,18,5,5,3,6,30,4,3,19,3,34,3
# 2          8,3,19,22,3,25,3,5,6,38,8,3,7,29,3,38,3
# 3         7,6,6,17,7,20,21,9,22,41,10,6,9,5,3,3,29
# 4         3,17,8,3,8,30,27,4,6,3,33,47,12,3,6,9,12
# ...                                            ...
# 2959        3,4,12,8,3,5,5,3,43,16,3,25,3,9,7,31,7
# 2960       5,3,43,16,3,25,3,9,7,31,7,17,9,3,40,7,6
# 2961     16,3,25,3,9,7,31,7,17,9,3,40,7,6,14,21,19
# 2962  19,41,25,3,11,3,18,3,19,6,12,10,20,19,5,17,3
# 2963        5,17,3,9,18,6,5,3,3,19,30,3,9,8,12,3,3
#
#                                                      10  11
# 0     -0.468713,-0.365825,-0.05716,0.560169,0.594466...   2
# 1     0.560169,0.583034,0.777378,0.708786,0.743082,0...   2
# 2     -0.102888,-0.160048,-0.125752,-0.274369,-0.262...   2
# 3     0.457281,-0.148616,0.194345,-0.011432,-0.02286...   2
# 4     -0.560169,-0.685922,-1.017451,-1.166067,-1.154...   2
# ...                                                 ...  ..
# 2959  0.840154,1.443645,1.100483,1.005818,1.183315,1...   2
# 2960  -1.242481,-1.100483,-1.159649,-1.289814,-1.325...   2
# 2961  -0.86382,-0.934819,-0.970319,-0.911153,-1.1004...   2
# 2962  0.792821,0.816488,0.721822,0.698156,0.650823,0...   2
# 2963  -0.437827,1.005818,0.804654,0.840154,0.165664,...   2
#
# [2964 rows x 12 columns]

# %% [markdown]
# # Split train and test

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, GridSearchCV, RepeatedStratifiedKFold
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import EditedNearestNeighbours, RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, f1_score

from collections import Counter


df_lambda_5mC_train, df_lambda_5mC_test = train_test_split(df_lambda_5mC,
                                                           train_size=0.5,
                                                           random_state=42)

df_lambda_5C_train, df_lambda_5C_test = train_test_split(df_lambda_5C,
                                                         train_size=0.5,
                                                         random_state=42)

# %%
df_lambda_5mC_train.shape, df_lambda_5C_train.shape
# Out:
# ((4000, 12), (5000, 12))

# %%
X_train = pd.concat([df_lambda_5mC_train, df_lambda_5C_train], axis=0).reset_index(drop=True)
X_test = pd.concat([df_lambda_5mC_test, df_lambda_5C_test], axis=0).reset_index(drop=True)

# %%
X_train.head(3)
# Out:
#          0      1  2      3                                     4  5   \
# 0  J02459.1   1479  +   1479  53e29230-e4a4-4427-ac0f-58e21bcf7a45  t
# 1  J02459.1   8634  +   8634  2abe484a-48eb-4ac0-8fbd-7f540f5e2c46  t
# 2  J02459.1  10559  -  37942  d95aa0fb-3ab4-4b4d-b4d6-f1b4141d2c49  t
#
#                   6                                                  7   \
# 0  AGAGACGCCGTTTGGCC  -0.447738,-0.75776,-0.776912,-1.042961,-0.5589...
# 1  GGTCGCCCCGCTGTTTT  -0.251688,-1.132387,0.855904,0.145893,-0.57564...
# 2  GACCAGATCGCCTACCG  -1.554025,-0.756328,1.181321,0.752899,-0.42717...
#
#                                                   8   \
# 0  0.132174,0.082434,0.063395,0.127124,0.115171,0...
# 1  0.090037,0.277638,0.044496,0.07361,0.083657,0....
# 2  0.103933,0.111726,0.115112,0.08139,0.119942,0....
#
#                                             9   \
# 0   26,3,5,6,12,7,15,18,3,5,7,21,73,3,36,15,13
# 1  14,8,5,11,12,26,18,3,3,5,8,48,10,7,19,13,30
# 2    5,15,14,16,12,42,9,25,3,14,7,7,8,7,7,7,10
#
#                                                   10  11
# 0  -0.46215,-0.362226,-0.374717,-0.362226,-0.4871...   1
# 1  -0.255841,-0.081404,-0.232583,-0.197695,-0.174...   1
# 2  -1.578306,-1.605286,-1.632265,-1.605286,-1.348...   1

# %%
X_train.tail(3)
# Out:
#             0      1  2      3                                     4  5   \
# 8997  J02459.1   8267  +   8267  dc898ea0-080a-415c-97b3-a4c1423cffeb  t
# 8998  J02459.1  29204  -  19297  ac08e884-af04-4af1-b610-b1852c5e7609  t
# 8999  J02459.1  19032  -  29469  b73bb5cb-93ed-41d8-9ddb-1b50a03a2010  t
#
#                      6                                                  7   \
# 8997  GCAGGCGTCGTAAAAAG  0.126927,0.953483,-0.375568,-1.072495,-0.31203...
# 8998  GACTGCTACGACCACTG  -0.890537,-1.003705,0.405333,1.035824,0.033122...
# 8999  CCACCTTCCGCACGGGC  0.413527,0.285782,-0.029564,0.612762,-0.52273,...
#
#                                                      8   \
# 8997  0.122529,0.117534,0.282255,0.129901,0.243602,0...
# 8998  0.121901,0.094497,0.134596,0.143695,0.133681,0...
# 8999  0.103299,0.116446,0.114766,0.10733,0.13682,0.1...
#
#                                                  9   \
# 8997   20,12,8,44,18,20,7,6,5,36,37,43,22,43,3,12,3
# 8998  16,3,49,6,8,3,19,17,6,32,19,21,23,69,25,30,41
# 8999    3,11,77,40,5,17,15,7,12,37,7,11,3,3,21,17,3
#
#                                                      10  11
# 8997  0.098108,0.282059,0.220742,0.282059,0.159425,0...   0
# 8998  -0.614267,-0.686534,-0.927423,-0.951512,-1.023...   0
# 8999  0.409512,0.542001,0.289067,0.469734,0.385423,0...   0

# %%
input_path='/fastscratch/c-panz/2021-11-21'
X_train.to_csv(os.path.join(input_path, 'train.tsv'), 
               header = None, index = None, sep = '\t')
X_test.to_csv(os.path.join(input_path, 'test.tsv'), 
               header = None, index = None, sep = '\t')
